# %%
from datetime import datetime

# SecureString parameter stored in AWS System Manager that holds a GitHub personal access token.
parameter_name = 'github_token'

# Org name to filter members
org_name = 'aws-amplify'

# Repositories for which reports will be generated.
repo_names = [
     'aws-amplify/amplify-js'
]

# Labels used across different repositories
issue_buckets = {
    'Bug': ['Bug', 'bug'],
    'Feature Request': ['Improvement', 'Feature Request', 'enhancement', 'feature-request'],
    'Question': ['Usage Question', 'Question', 'question'],
    'Pending Triage': ['Pending Triage', 'to-be-reproduced']
}

# Labels to omit from rows
omit_labels = {
    'Wont Fix', "Won't Fix", 'closing-soon-if-no-response', 'Product Review',
    'Requesting Feedback', 'Closing Soon', 'Clarification Needed', 'Duplicate',
    'Needs Info from Requester', 'work-in-progress', 'good-first-issue',
    'pending-close-response-required', 'pending-response', 'pending-release',
    'Awaiting Release', 'Investigating', 'Pending', 'Pull Request', 'duplicate',
    'good first issue', 'Reviewing', 'needs review', 'needs discussion',
    'needs-review', 'investigating', 'help wanted', 'needs-discussion',
    'Help Wanted', 'Good First Issue', 'wontfix'
}
omit_labels = omit_labels.union({label for labels in issue_buckets.values() for label in labels})

# Capture start time
start = datetime.now()

# %%
# Retrieve the GitHub token from SSM to prevent oops-I-pushed-credentials-to-GitHub uh-ohs.

import boto3

ssm = boto3.client('ssm')
response = ssm.get_parameter(Name=parameter_name, WithDecryption=True)
token = response['Parameter']['Value']

# %%
# Grab all issues from the GitHub V4 GraphQL API

import requests
import json

headers = {'Authorization': f'Bearer {token}'}


def get_issues(owner, name, *, end_cursor=None):
    query = """
    query($owner: String!, $name: String!, $endCursor: String) {
      repository(owner:$owner, name:$name) {
        issues(first:50, after:$endCursor) {
          nodes {
            number
            title
            createdAt
            closedAt
            author {
              login
            }
            reactions {
                totalCount
            }
            reactionGroups {
              users(first:50, after:$endCursor) {
                  nodes {
                      login
                  }
              }
            }
            comments(first:100, after:$endCursor) {
              nodes {
                createdAt
                author {
                  login
                }
                reactions {
                  totalCount
                }
                reactionGroups {
                    users(first:50, after:$endCursor) {
                        nodes {
                          login
                        }
                    }
                }
              }
            }
            labels(first:10) {
              nodes {
                name
              }
            }
          }
          pageInfo {
            hasNextPage
            endCursor
          }
        }
      }
    }"""
    
    variables = {'owner': owner, 'name': name, 'endCursor': end_cursor}
    response = execute(query, variables)
    page_info = response['data']['repository']['issues']['pageInfo']
    nodes = response['data']['repository']['issues']['nodes']
    
    for issue in nodes:
        yield issue
    
    if page_info['hasNextPage']:
        yield from get_issues(owner, name, end_cursor=page_info['endCursor'])
        
        
def get_members(login, *, end_cursor=None):
    query = """
    query($login: String!, $endCursor: String) {
      organization(login: $login) {
        membersWithRole(first:100, after:$endCursor) {
          nodes {
            login
          }
          pageInfo {
            hasNextPage
            endCursor
          }
        }
      }
    }"""
    
    variables = {'login': login, 'endCursor': end_cursor}
    response = execute(query, variables)
    page_info = response['data']['organization']['membersWithRole']['pageInfo']
    nodes = response['data']['organization']['membersWithRole']['nodes']
    
    for member in nodes:
        yield member['login']
    
    if page_info['hasNextPage']:
        yield from get_members(login, end_cursor=page_info['endCursor'])
        
    
def execute(query, variables):
    request = requests.post(
        'https://api.github.com/graphql',
        json={'query': query, 'variables': variables},
        headers=headers
    )

    if request.status_code == 200:
        return request.json()
    else:
        raise Exception("{}: {}".format(request.status_code, query))

# %%
# Loop through each repository, grab all issues, and create a DataFrame for each.

import pandas as pd

repos = {}
bucket_lookup = {label: bucket for bucket, labels in issue_buckets.items() for label in labels}
staff = set(get_members(org_name))

for repo_name in repo_names:
    issues = []
    owner, name = repo_name.split('/')

    for issue in get_issues(owner, name):
        labels = pd.array([label['name'] for label in issue['labels']['nodes']])
        bucket = 'Other'
        created_at = pd.Timestamp(issue['createdAt'],tz='UTC')

        score = 1
        score += len(issue['comments']['nodes'])
        score += issue['reactions']['totalCount']
        score += sum(comment['reactions']['totalCount'] for comment in issue['comments']['nodes'])
        
        if issue['author']:
            impacted = {issue['author']['login']}
        else:
            impacted = set()
            
        impacted |= {comment['author']['login'] for comment in issue['comments']['nodes']
                                                if comment['author']}
        impacted |= {user['login'] for group in issue['reactionGroups'] for user in group['users']['nodes']}
        impacted |= {user['login'] for comment in issue['comments']['nodes']
                                   for group in comment['reactionGroups']
                                   for user in group['users']['nodes']}
        
        impact = len(impacted - staff)
        
        if issue['closedAt']:
            closed_at = pd.Timestamp(issue['closedAt'], tz='UTC')
        else:
            closed_at = None
            
        for label in labels:
            if label in bucket_lookup:
                bucket = bucket_lookup[label]
                break
                
        issues.append(
            [issue['number'], issue['title'], labels, created_at, closed_at, bucket, score, impact]
        )
        
    repos[repo_name] = pd.DataFrame(issues, columns=[
        'id', 'title', 'labels', 'created_at', 'closed_at', 'bucket', 'score', 'impact'
    ])

# %%
# Top Open Bugs by Activity

from IPython.core.display import HTML

pd.set_option('display.max_colwidth', None)

display(HTML(f'<h1>Top Open Bugs by Impact</h1>'))

for repo_name, df in repos.items():
    df = df.loc[df.bucket == 'Bug']
    df = df[~(df.closed_at > '1970-01-01')]
    df = df.sort_values(axis=0, by=['impact'], ascending=False)

    display(HTML(f'<h2>{repo_name}</h2>'))
    display(df[['id', 'title', 'created_at', 'labels', 'score', 'impact']].head(50))
# Out:
# <h1>Top Open Bugs by Impact</h1>
# <h2>aws-amplify/amplify-js</h2>
#         id  \
# 2675  4257
# 2591  4089
# 3701  6108
# 3452  5623
# 2672  4244
# 3812  6327
# 2737  4346
# 2186  3431
# 2981  4754
# 2648  4197
# 2673  4245
# 745   1226
# 3248  5218
# 2472  3876
# 3837  6388
# 3820  6347
# 3637  6000
# 2451  3844
# 3806  6318
# 3929  6580
# 3828  6363
# 2169  3402
# 3726  6162
# 3616  5963
# 2144  3369
# 3192  5120
# 3709  6128
# 3667  6056
# 3827  6358
# 3833  6378
# 3227  5173
# 4000  6737
# 3204  5135
# 4028  6786
#
#                                                                                            title  \
# 2675                        GraphQLResult and Observable<object> incorrect types for API.graphql
# 2591                                         support RN-0.60.+ for @aws-amplify/pushnotification
# 3701      DataStore with @auth - Sync error subscription failed ... Missing field argument owner
# 3452                             Custom auth lambda trigger is not configured for the user pool.
# 2672                          React-native Auth.federatedSignIn() redirection URL mismatch error
# 3812   Custom auth lambda trigger is not configured for the user pool -> on Sign Up Confirmation
# 2737                                     Amplify auth signIn throws Cors error on Microsoft Edge
# 2186                                                    Delete linked user from User pool users.
# 2981                         implicitly has an 'any' type (zen-observable, graphql/language/ast)
# 2648                                                        Amplify currentUserinfo returns null
# 2673                                                 Using AsyncStorage overwrites Amplify JWT's
# 745                              Auth.setupTOTP silently disables TOTP if it's currently enabled
# 3248       Using custom state with Cognito Hosted UI leads to OAuth Error while validating state
# 2472               Cognito doesn't invoke the "Define auth challenge" for users with enabled MFA
# 3837                                             Angular Material input not behaving as expected
# 3820                                         Cognito authorization code grant flow does not work
# 3637                                                App doesn't open on tapping the Notification
# 2451                                     setPreferredMfa: User has not set up software token mfa
# 3806                      Fails to load in an private/incognito browser session within an iframe
# 3929                               DataStore upgrading from 2.2.6 to 2.2.7+ breaks realtime data
# 3828                            DataStore latter updates should take precedent on a slow network
# 2169                                                                           Login Not Allowed
# 3726     Datastore timeout when internet drops intermittently and app in background for too long
# 3616                                     [Datastore] Improve error handling when data is syncing
# 2144  aws-amplify-react  Connect mutation does not handle errors in graphQL operation correctly.
# 3192                                                 TOTP Setup and Useage with AWS Amplify Auth
# 3709                                          DataStore unable to delete item right after update
# 3667                                               Resend Code link broken when using formFields
# 3827                           DataStore breaks when record is constantly queried after updating
# 3833                                   IE11 - Object doesn't support property or method 'assign'
# 3227                                   Sync processor does not follow @model subscriptions level
# 4000                                                        User friendly invalid username error
# 3204                             [DataStore] How to handle errors when save with condition fails
# 4028                             SSR not working with @aws-amplify/ui-react AmplifyAuthenticator
#
#                     created_at  \
# 2675 2019-10-25 04:09:48+00:00
# 2591 2019-09-26 16:34:03+00:00
# 3701 2019-12-20 08:37:36+00:00
# 3452 2020-04-29 20:45:07+00:00
# 2672 2019-10-24 12:53:29+00:00
# 3812 2020-07-14 23:55:10+00:00
# 2737 2019-11-05 16:36:10+00:00
# 2186 2019-06-11 18:24:57+00:00
# 2981 2020-01-22 08:51:08+00:00
# 2648 2019-10-17 03:45:24+00:00
# 2673 2019-10-24 14:02:33+00:00
# 745  2018-07-12 21:57:15+00:00
# 3248 2020-03-27 21:22:28+00:00
# 2472 2019-08-20 14:43:21+00:00
# 3837 2020-07-22 08:19:17+00:00
# 3820 2020-07-17 03:58:55+00:00
# 3637 2020-06-03 23:24:10+00:00
# 2451 2019-08-13 15:56:22+00:00
# 3806 2020-07-14 02:19:32+00:00
# 3929 2020-08-14 17:55:57+00:00
# 3828 2020-07-18 19:32:18+00:00
# 2169 2019-06-05 12:56:47+00:00
# 3726 2020-06-25 10:21:21+00:00
# 3616 2020-06-01 16:34:07+00:00
# 2144 2019-05-30 23:59:16+00:00
# 3192 2020-03-17 13:01:58+00:00
# 3709 2020-06-19 19:08:12+00:00
# 3667 2020-06-11 03:08:55+00:00
# 3827 2020-07-18 06:07:16+00:00
# 3833 2020-07-21 00:28:01+00:00
# 3227 2020-03-23 22:06:52+00:00
# 4000 2020-09-07 11:20:47+00:00
# 3204 2020-03-18 17:29:19+00:00
# 4028 2020-09-14 22:28:14+00:00
#
#                                                       labels  score  impact
# 2675                                          [GraphQL, bug]     62      44
# 2591  [Push Notifications, React Native, bug, documentation]     67      35
# 3701                                        [DataStore, bug]     94      30
# 3452                      [Amplify UI Components, Auth, bug]     29      19
# 2672                [Auth, React Native, bug, documentation]     39      19
# 3812                      [Amplify UI Components, Auth, bug]     41      17
# 2737                      [Browser Compatibly, Cognito, bug]     40      14
# 2186                            [Cognito, Service Team, bug]     21      10
# 2981                                  [TypeScript, Vue, bug]     13       9
# 2648                            [Cognito, Service Team, bug]     54       9
# 2673                                     [React Native, bug]     12       9
# 745                             [Cognito, Service Team, bug]     17       8
# 3248                                             [Auth, bug]     13       6
# 2472                   [Cognito, Service Team, bug, tracked]      7       4
# 3837                   [Amplify UI Components, Angular, bug]     10       4
# 3820                                 [Auth, Federation, bug]      4       4
# 3637                 [Push Notifications, React Native, bug]      6       4
# 2451                            [Cognito, Service Team, bug]      5       4
# 3806                                           [PubSub, bug]     11       3
# 3929                                        [DataStore, bug]     65       3
# 3828                          [DataStore, React Native, bug]      4       2
# 2169                            [Cognito, Service Team, bug]     11       2
# 3726                          [DataStore, React Native, bug]     14       2
# 3616                                        [DataStore, bug]      4       2
# 2144                        [GraphQL, bug, good first issue]      4       2
# 3192                            [Cognito, Service Team, bug]      3       1
# 3709                                        [DataStore, bug]      3       1
# 3667                            [Amplify UI Components, bug]      1       1
# 3827                                        [DataStore, bug]      4       1
# 3833                                             [Core, bug]      3       1
# 3227                                        [DataStore, bug]      1       1
# 4000                            [Amplify UI Components, bug]      1       1
# 3204                                        [DataStore, bug]      3       0
# 4028                       [Amplify UI Components, SSR, bug]      3       0

# %%
# Top Open Feature Requests by Activity

display(HTML(f'<h1>Top Open Feature Requests by Impact</h1>'))

for repo_name, df in repos.items():
    df = df.loc[df.bucket == 'Feature Request']
    df = df[~(df.closed_at > '1970-01-01')]
    df = df.sort_values(axis=0, by=['impact'], ascending=False)
    
    display(HTML(f'<h2>{repo_name}</h2>'))
    display(df[['id', 'title', 'created_at', 'labels', 'score', 'impact']].head(50))
# Out:
# <h1>Top Open Feature Requests by Impact</h1>
# <h2>aws-amplify/amplify-js</h2>
#         id  \
# 38      54
# 2188  3435
# 1003  1613
# 491    825
# 185    329
# 741   1218
# 394    661
# 3191  5119
# 629   1035
# 650   1067
# 595    991
# 2248  3524
# 2328  3640
# 1297  2089
# 255    439
# 2291  3591
# 1224  1972
# 1753  2777
# 1249  2010
# 2215  3474
# 891   1437
# 424    717
# 385    639
# 2973  4744
# 1132  1824
# 1532  2455
# 2234  3499
# 1923  3044
# 41      61
# 1174  1896
# 2475  3882
# 699   1145
# 1490  2390
# 2530  3974
# 1426  2286
# 2917  4652
# 607   1006
# 1716  2714
# 3177  5101
# 2173  3410
# 3090  4957
# 3577  5901
# 1701  2692
# 3481  5703
# 1114  1792
# 1306  2102
# 3703  6113
# 309    518
# 1657  2624
# 2872  4579
#
#                                                                                                                  title  \
# 38                         How to find the bidirectional map between Cognito identity ID and Cognito user information?
# 2188                                                                 cognito.user.signOut() does not invalidate tokens
# 1003                                                                                      AppSync, AWS Amplify and SSR
# 491                                                                      Possible to set current credentials manually?
# 185                                                                                      Support for multiple buckets?
# 741                                                                   SPA with Implicit Grant - handling token refresh
# 394                                                              Feature Request: Support for multiple Auth user pools
# 3191                                                            DataStore: support for multi-tenant apps with sharing?
# 629                                                                                           Nativescript aws amplify
# 650                                            How to verify if a user with a given email already exists in User Pool?
# 595                                                                                Auto signin after successful signup
# 2248                                                              Ability for `Logger` to ship logs to CloudWatch Logs
# 2328                                         Is there a simple way to check if the user is logged in or not (in code)?
# 1297                                                            Switching Unauthenticated Users to Authenticated Users
# 255                                                                                               Support for SAML IDP
# 2291                                                                          Support API Gateway websockets to PubSub
# 1224                                                                                             Force Token to Expire
# 1753                                                                    Email verification only sending code, not link
# 1249                                                                                              Resend MFA Code Hook
# 2215                                                                                     Angular Universal SSR Support
# 891                                                                                  API: Add support to send FormData
# 424                                  Feature: Alternate signup method requires only email and sends temporary password
# 385                                                                               Correct way of using currentSession
# 2973                                                                           angular 9 with amplify authenticator UI
# 1132                                        Enabling federation to AWS via Cognito User Pool using AD, ADFS, and SMAL2
# 1532                                        Ionic 4 / Angular 7 - aws amplify doesn't have Federated Sign in / Sign up
# 2234                 Vue.js + TypeScript build error, `Could not find a declaration file for module '@aws-amplify/ui'`
# 1923                                                                                                   .NET C# support
# 41                                                                    [feature request] s3 multipart resumable uploads
# 1174                                                                      Cognito passwordless authentication via link
# 2475                          After successful registration and confirmation, how can we login the user automatically?
# 699                                                   Storage.get('file') should throw an error if file does not exist
# 1490                                                                             User pool groups policies not applied
# 2530                                                                                                 Release Changelog
# 1426                                                                  Add typings support for aws-amplify-react-native
# 2917                                                                                 DataStore: How to do a sort-query
# 607                                                                                    Handling authentication offline
# 1716                                                                          How to set session token expiry timeout?
# 3177                                           Error after after hot update: "The schema has already been initialized"
# 2173                        withOAuth + facebookSignIn confusing permission request / new users not signed to facebook
# 3090  How to i tell Datastore to query appsync with a customerId? The Datastore.query only queries the local database.
# 3577                                                                                                    Public Roadmap
# 1701                                                     How to catch PubSub errors if MQTT connection lost or broken?
# 3481                                                                              Auth components don't support scopes
# 1114                                                   Is there a synchronous way to see if the user is authenticated?
# 1306                                       You can confirm emails you don't own if multifactor is turned on in Cognito
# 3703                            using @aws-amplify/ui-react how to fully customize the Auth flows documentation needed
# 309                   aws-amplify Storage.get() and S3Image components should allow access for public files in buckets
# 1657                                                                                     RFC AWS amplify-js changelog
# 2872                                                                                      Datastore usage with Storage
#
#                     created_at  \
# 38   2017-12-10 23:17:19+00:00
# 2188 2019-06-12 09:36:41+00:00
# 1003 2018-09-11 15:30:13+00:00
# 491  2018-05-11 14:52:19+00:00
# 185  2018-02-21 18:49:36+00:00
# 741  2018-07-12 06:18:14+00:00
# 394  2018-04-15 23:55:42+00:00
# 3191 2020-03-17 12:40:28+00:00
# 629  2018-06-15 18:04:38+00:00
# 650  2018-06-20 17:58:26+00:00
# 595  2018-06-06 07:13:23+00:00
# 2248 2019-06-24 20:24:55+00:00
# 2328 2019-07-13 01:39:13+00:00
# 1297 2018-11-12 09:36:42+00:00
# 255  2018-03-13 02:54:34+00:00
# 2291 2019-07-04 01:36:20+00:00
# 1224 2018-10-24 00:16:14+00:00
# 1753 2019-02-28 12:54:22+00:00
# 1249 2018-10-30 07:15:07+00:00
# 2215 2019-06-08 22:10:16+00:00
# 891  2018-08-13 13:07:35+00:00
# 424  2018-04-24 02:48:27+00:00
# 385  2018-04-12 08:00:37+00:00
# 2973 2020-01-20 13:48:23+00:00
# 1132 2018-10-03 10:53:00+00:00
# 1532 2019-01-03 14:44:53+00:00
# 2234 2019-06-20 15:38:53+00:00
# 1923 2019-04-09 07:02:42+00:00
# 41   2017-12-12 11:25:21+00:00
# 1174 2018-10-12 22:32:39+00:00
# 2475 2019-08-21 00:37:17+00:00
# 699  2018-06-29 08:49:59+00:00
# 1490 2018-12-20 17:20:14+00:00
# 2530 2019-09-05 13:35:37+00:00
# 1426 2018-12-07 23:49:22+00:00
# 2917 2019-12-29 00:12:20+00:00
# 607  2018-06-11 14:15:48+00:00
# 1716 2019-02-14 22:46:24+00:00
# 3177 2020-03-15 13:06:12+00:00
# 2173 2019-06-06 14:53:45+00:00
# 3090 2020-02-19 19:51:46+00:00
# 3577 2020-05-26 14:22:24+00:00
# 1701 2019-02-12 12:40:57+00:00
# 3481 2020-05-06 17:30:34+00:00
# 1114 2018-10-01 12:07:09+00:00
# 1306 2018-11-13 23:16:08+00:00
# 3703 2020-06-18 16:16:32+00:00
# 309  2018-03-25 22:19:59+00:00
# 1657 2019-01-30 01:05:57+00:00
# 2872 2019-12-15 09:36:58+00:00
#
#                                                             labels  score  \
# 38                  [Auth, Cognito, Service Team, feature-request]    463
# 2188                      [Cognito, Service Team, feature-request]    404
# 1003                               [AppSync, SSR, feature-request]    320
# 491                          [Auth, feature-request, needs-review]    143
# 185                                     [Storage, feature-request]    119
# 741                     [Auth, Service Team, Vue, feature-request]     91
# 394                                        [Auth, feature-request]     87
# 3191                                  [DataStore, feature-request]    190
# 629                                              [feature-request]    109
# 650                                     [Cognito, feature-request]     74
# 595                         [Auth, documentation, feature-request]     81
# 2248                                       [Core, feature-request]     61
# 2328                                       [Auth, feature-request]     72
# 1297                              [Auth, Cognito, feature-request]     89
# 255                                        [Auth, feature-request]     57
# 2291                                        [API, feature-request]     47
# 1224  [Auth, Cognito, React Native, Service Team, feature-request]     85
# 1753                      [Cognito, Service Team, feature-request]     47
# 1249                              [Auth, Cognito, feature-request]     59
# 2215                               [Angular, SSR, feature-request]     45
# 891                                         [API, feature-request]     45
# 424                               [Auth, Cognito, feature-request]     34
# 385                         [Auth, documentation, feature-request]     46
# 2973                                    [Angular, feature-request]     46
# 1132                     [Cognito, documentation, feature-request]     38
# 1532                       [Angular, Auth, Ionic, feature-request]     51
# 2234                            [TypeScript, Vue, feature-request]     27
# 1923                                             [feature-request]     27
# 41                                      [Storage, feature-request]     49
# 1174                                       [Auth, feature-request]     46
# 2475                                    [Cognito, feature-request]     21
# 699                                     [Storage, feature-request]     28
# 1490                              [Auth, Cognito, feature-request]     32
# 2530                                             [feature-request]     28
# 1426                               [React Native, feature-request]     22
# 2917                                  [DataStore, feature-request]     34
# 607                      [Auth, feature-request, good first issue]     20
# 1716       [Auth, Cognito, Service Team, Storage, feature-request]     20
# 3177                                        [SSR, feature-request]     22
# 2173                         [Auth, React Native, feature-request]     24
# 3090                                  [DataStore, feature-request]     25
# 3577                                             [feature-request]     26
# 1701                                     [PubSub, feature-request]     30
# 3481                      [Amplify UI Components, feature-request]     38
# 1114                                    [Cognito, feature-request]     19
# 1306                                    [Cognito, feature-request]     48
# 3703                      [Amplify UI Components, feature-request]     20
# 309                                     [Storage, feature-request]     24
# 1657                             [Build, Tooling, feature-request]     19
# 2872                                  [DataStore, feature-request]     19
#
#       impact
# 38       168
# 2188     168
# 1003     146
# 491       79
# 185       78
# 741       57
# 394       56
# 3191      56
# 629       55
# 650       54
# 595       54
# 2248      48
# 2328      44
# 1297      41
# 255       37
# 2291      36
# 1224      35
# 1753      31
# 1249      30
# 2215      30
# 891       30
# 424       27
# 385       26
# 2973      26
# 1132      25
# 1532      25
# 2234      24
# 1923      24
# 41        23
# 1174      22
# 2475      21
# 699       20
# 1490      19
# 2530      18
# 1426      17
# 2917      17
# 607       17
# 1716      17
# 3177      16
# 2173      16
# 3090      16
# 3577      16
# 1701      16
# 3481      16
# 1114      15
# 1306      15
# 3703      15
# 309       15
# 1657      15
# 2872      14

# %%
# Closed Issue Report

from IPython.core.display import HTML
import pytz

pd.set_option('display.max_colwidth', None)

display(HTML(f'<h1>Closed Issues by Impact</h1>'))

thirty_days_ago = datetime.now() - pd.Timedelta('30 days')
thirty_days_ago = seven_days_ago.astimezone(pytz.timezone('UTC'))

for repo_name, df in repos.items():
    df = df[(df.closed_at > thirty_days_ago)]
    df = df.sort_values(axis=0, by=['impact'], ascending=False)

    display(HTML(f'<h2>{repo_name}</h2>'))
    display(df[['id', 'title', 'created_at', 'closed_at', 'labels', 'score', 'impact']])
# Out:
# <h1>Closed Issues by Impact</h1>
# <h2>aws-amplify/amplify-js</h2>
#         id  \
# 3698  6104
# 3352  5403
# 3875  6469
# 3974  6685
# 3871  6462
# 3498  5738
# 4012  6755
# 4024  6775
# 4022  6770
# 4021  6769
# 4020  6768
# 3979  6695
# 3989  6710
# 3985  6703
# 3977  6692
# 3945  6611
# 3897  6517
# 4025  6777
#
#                                                                                                                  title  \
# 3698                                                                      [RFC]: Amplify Storage UI Component Refactor
# 3352                                                                             No notification when websocket closes
# 3875                                                                      Authenticator shows additional social button
# 3974                                                                       @aws-sdk v1.0.0-gamma.4 does not export ESM
# 3871                                            Credentials._setCredentialsFromSession generates invalid provider name
# 3498                                                 AWSPinPointProvider: Security Token Expires after some inactivity
# 4012                                                                Auth.updateUserAttribute sends a verification code
# 4024                                         The conditional request fails when updating sort key of the primary index
# 4022                                                 Federation requires either a User Pool or Identity Pool in config
# 4021                                                                        packages too large, how can it be reduced?
# 4020                                                 Federation requires either a User Pool or Identity Pool in config
# 3979                           Mixed Content: was loaded over HTTPS, but requested an insecure XMLHttpRequest endpoint
# 3989                       AmplifyAuthenticator - Verify Contact Information Screen displays "your.adress@example.com"
# 3985                                                                               Async Storage -- AWS amplify error
# 3977                        Is it possible to customize/change the default username generated for identify federation?
# 3945                                                     DataStore.save incorrectly sends the whole item when Updating
# 3897  Owner auth API provisioned with CLI 4.22.1 without read operation do not require owner input on subscription API
# 4025                                                                                       amplify storage returns 403
#
#                     created_at                 closed_at  \
# 3698 2020-06-17 09:33:35+00:00 2020-09-14 21:53:39+00:00
# 3352 2020-04-14 10:11:04+00:00 2020-09-10 16:24:21+00:00
# 3875 2020-08-01 14:51:09+00:00 2020-09-11 22:31:17+00:00
# 3974 2020-08-29 08:41:25+00:00 2020-09-10 09:23:40+00:00
# 3871 2020-07-31 10:33:58+00:00 2020-09-11 02:31:21+00:00
# 3498 2020-05-10 18:55:47+00:00 2020-09-12 20:33:18+00:00
# 4012 2020-09-09 03:05:37+00:00 2020-09-11 19:07:11+00:00
# 4024 2020-09-11 07:31:52+00:00 2020-09-14 16:58:42+00:00
# 4022 2020-09-10 16:32:28+00:00 2020-09-11 09:44:53+00:00
# 4021 2020-09-10 16:35:43+00:00 2020-09-10 19:43:53+00:00
# 4020 2020-09-10 16:33:11+00:00 2020-09-11 10:36:34+00:00
# 3979 2020-08-31 23:05:10+00:00 2020-09-10 15:24:27+00:00
# 3989 2020-09-02 20:11:06+00:00 2020-09-09 21:01:32+00:00
# 3985 2020-09-01 23:17:37+00:00 2020-09-11 01:08:58+00:00
# 3977 2020-08-29 14:33:30+00:00 2020-09-10 23:06:49+00:00
# 3945 2020-08-20 21:08:39+00:00 2020-09-08 12:21:35+00:00
# 3897 2020-08-05 21:00:03+00:00 2020-09-12 20:33:19+00:00
# 4025 2020-09-11 15:33:03+00:00 2020-09-12 13:57:48+00:00
#
#                                                                        labels  \
# 3698                        [Amplify UI Components, Storage, feature-request]
# 3352                                                            [PubSub, bug]
# 3875  [Amplify UI Components, investigating, pending-close-response-required]
# 3974                                                            [Build, Core]
# 3871                   [Auth, investigating, pending-close-response-required]
# 3498                                        [pending-close-response-required]
# 4012                                       [Auth, question, to-be-reproduced]
# 4024                                         [API, GraphQL, to-be-reproduced]
# 4022                                                            [Auth, OAuth]
# 4021                                                               [question]
# 4020                                                    [Auth, SSR, question]
# 3979                                                       [to-be-reproduced]
# 3989                                [Amplify UI Components, needs-discussion]
# 3985                                         [React Native, to-be-reproduced]
# 3977                                             [Auth, Federation, question]
# 3945                                            [DataStore, to-be-reproduced]
# 3897                             [API, Auth, pending-close-response-required]
# 4025                                         [Amplify UI Components, Storage]
#
#       score  impact
# 3698     21       7
# 3352     15       5
# 3875      6       3
# 3974     15       3
# 3871     11       2
# 3498     24       2
# 4012      1       1
# 4024      1       1
# 4022      1       1
# 4021      1       1
# 4020      1       1
# 3979      2       1
# 3989      4       1
# 3985     13       1
# 3977      3       1
# 3945      4       1
# 3897      3       1
# 4025      1       1

# %%
from datetime import datetime
from IPython.display import display, HTML

total = (datetime.now() - start).seconds
minutes, seconds = divmod(total, 60)

if minutes:
    display(HTML(f'<em>Report generation took {minutes}min, {seconds}sec'))
else:
    display(HTML(f'<em>Report generation took {seconds}sec'))
